# %%
import pandas as pd

# %%
df = pd.read_csv('./df_PEG_final(2).csv')
df
# Out:
#       거래소코드          회사명  회계년도        PEG
# 0     58820     (주)CMG제약  2011   0.000000
# 1     58820     (주)CMG제약  2012   0.000000
# 2     58820     (주)CMG제약  2013  14.256033
# 3     58820     (주)CMG제약  2014  23.557141
# 4     58820     (주)CMG제약  2015   0.000000
# ...     ...          ...   ...        ...
# 9706  25530  (주)에스제이엠홀딩스  2015   0.101062
# 9707  25530  (주)에스제이엠홀딩스  2016   0.066509
# 9708  25530  (주)에스제이엠홀딩스  2017   0.203981
# 9709  25530  (주)에스제이엠홀딩스  2018  -0.519606
# 9710  25530  (주)에스제이엠홀딩스  2019  -2.219475
#
# [9711 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9711 entries, 0 to 9710
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   거래소코드   9711 non-null   int64
#  1   회사명     9711 non-null   object
#  2   회계년도    9711 non-null   int64
#  3   PEG     9711 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 303.6+ KB

# %%
df_1 = pd.read_csv('./final_2.csv')

# %%
df.columns = ['거래소코드1', '회사명1', '회계년도1', 'PEG']

# %%
df_t = pd.concat((df_1, df), axis=1)
df_t.drop(['거래소코드1', '회사명1', '회계년도1'], axis=1, inplace=True)

# %%
df_t
# Out:
#       거래소코드    PBR      PER  기업규모코드          매출액  매출액순이익률  매출액증가율      성장비용  \
# 0     58820  2.210    0.000    20.0   17751704.0    -8.50   56.40  376118.0
# 1     58820  2.555    0.000    20.0   16255389.0   -40.97   -8.43  401085.0
# 2     58820  2.945  375.055    20.0   20402140.0     1.45   25.51  243898.0
# 3     58820  2.855  646.030    20.0   22752584.0     0.69   11.52  215128.0
# 4     58820  5.915    0.000    20.0   27041894.0   -13.50   18.85  195671.0
# ...     ...    ...      ...     ...          ...      ...     ...       ...
# 9706  25530  0.630    7.085    30.0  185141914.0    13.39   14.33       0.0
# 9707  25530  0.630   14.515    30.0  181367297.0     8.36   -2.04       0.0
# 9708  25530  0.550    5.130    30.0  169845355.0    11.37   -6.35       0.0
# 9709  25530  0.400   16.740    20.0  160740722.0     3.83   -5.36       0.0
# 9710  25530  0.320    9.590    20.0  160751444.0     5.81    0.01       0.0
#
# ...

# %%
df_t.to_csv('total_1.csv', index=False)
