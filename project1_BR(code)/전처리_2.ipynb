# %%
import pandas as pd

df = pd.read_csv('./data.csv')
df
# Out:
#               회사명   거래소코드     회계년도  자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  \
# 0      (주)BNK금융지주  138930  2011/12     3.249906e+09     2.727816e+09
# 1      (주)BNK금융지주  138930  2012/12     3.403623e+09     2.740568e+09
# 2      (주)BNK금융지주  138930  2013/12     3.507652e+09     2.737860e+09
# 3      (주)BNK금융지주  138930  2014/12     4.539500e+09     3.550847e+09
# 4      (주)BNK금융지주  138930  2015/12     5.244360e+09     4.086109e+09
# ...           ...     ...      ...              ...              ...
# 18459     흥아해운(주)    3280  2015/12     7.712121e+08     1.618245e+08
# 18460     흥아해운(주)    3280  2016/12     9.425868e+08     1.838293e+08
# 18461     흥아해운(주)    3280  2017/12     8.341074e+08     1.076150e+08
# 18462     흥아해운(주)    3280  2018/12     7.827870e+08     5.673155e+07
# 18463     흥아해운(주)    3280  2019/12     3.865508e+08     1.763223e+07
#
#        부채(*)(IFRS)(천원)  매출액(영업수익)(*)(연결)(천원)  *주당순손익(IFRS연결)(천원)  \
# 0         5.220902e+08          3.057370e+09              2120.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18464 entries, 0 to 18463
# Data columns (total 44 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   회사명                                 18464 non-null  object
#  1   거래소코드                               18464 non-null  int64
#  2   회계년도                                18464 non-null  object
#  3   자산(*)(IFRS)(천원)                     17037 non-null  float64
#  4   자본(*)(IFRS)(천원)                     17037 non-null  float64
#  5   부채(*)(IFRS)(천원)                     17037 non-null  float64
#  6   매출액(영업수익)(*)(연결)(천원)                12823 non-null  float64
#  7   *주당순손익(IFRS연결)(천원)                  12816 non-null  float64
#  8   경상연구개발비(IFRS연결)(천원)                 12816 non-null  float64
#  9   광고 및 판매촉진비(IFRS연결)(천원)              12816 non-null  float64
#  10  임차료 및 리스료(IFRS연결)(천원)               12816 non-null  float64
# ...

# %%
df.describe()
# Out:
#                거래소코드  자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  부채(*)(IFRS)(천원)  \
# count   18464.000000     1.703700e+04     1.703700e+04     1.703700e+04
# mean    91610.701906     1.445225e+09     5.938549e+08     8.513700e+08
# std    110043.801086     9.982573e+09     4.097583e+09     7.714782e+09
# min        20.000000     0.000000e+00    -7.036541e+08     0.000000e+00
# 25%     17385.000000     6.295597e+07     3.752947e+07     1.667494e+07
# 50%     58110.000000     1.297147e+08     7.825002e+07     4.458396e+07
# 75%    121440.000000     3.449044e+08     1.936714e+08     1.343378e+08
# max    950220.000000     2.947737e+11     1.778702e+11     2.732731e+11
#
#        매출액(영업수익)(*)(연결)(천원)  *주당순손익(IFRS연결)(천원)  경상연구개발비(IFRS연결)(천원)  \
# count          1.282300e+04        12816.000000         1.281600e+04
# mean           1.584978e+09          301.902310         2.244069e+06
# std            8.103886e+09         4167.455005         2.263131e+07
# ...

# %%
df['기업규모코드'].value_counts()
# Out:
# 20.0    8383
# 30.0    7391
# 10.0    1830
# 90.0     466
# 0.0      394
# Name: 기업규모코드, dtype: int64

# %%
df['기업규모명'].value_counts()
# Out:
# 중소기업    8679
# 중견기업    7457
# 대기업     1830
# 기타       498
# Name: 기업규모명, dtype: int64

# %% [markdown]
# - 기업규모코드 컬럼과 기업규모명 컬럼은 겹치는 항목일 수 있기 때문에 value_counts()로 서로 값들을 비교해봤는데 서로 맞지 않는다.
# - 코드는 0, 10, 20, 30, 90 5개의 범주 / 규모명은 중소기업, 중견기업, 대기업, 기타의 4개 범주
# - 대기업의 숫자와 코드 10의 숫자가 같은것으로 볼때 코드 10과 대기업은 같은것으로 볼 수 있다.
# - 코드 컬럼의 0은 대기업을 제외한 중소기업 일부, 기타 일부와 중견기업 일부를 나타낸다.

# %%
# 기업규모명에 맞춰 기업규모코드 입력하기
df.loc[df['기업규모명'] == '중소기업', '기업규모코드'] = 20.0
df.loc[df['기업규모명'] == '중견기업', '기업규모코드'] = 30.0
df.loc[df['기업규모명'] == '기타', '기업규모코드'] = 90.0
df.loc[df['기업규모명'] == '대기업', '기업규모코드'] = 10.0

# %%
df['기업규모코드'].value_counts()
# Out:
# 20.0    8679
# 30.0    7457
# 10.0    1830
# 90.0     498
# Name: 기업규모코드, dtype: int64

# %%
df['기업규모명'].value_counts()
# Out:
# 중소기업    8679
# 중견기업    7457
# 대기업     1830
# 기타       498
# Name: 기업규모명, dtype: int64

# %% [markdown]
# - 기업규모코드 컬럼의 0.0 삭제 / 기업규모명 컬럼과 값 맞추기 완료

# %% [markdown]
# ## 연도별 기업 수
# - 2011/12 : 1722
# - 2012/12 : 1768
# - 2013/12 : 1826
# - 2014/12 : 1915
# - 2015/12 : 2003
# - 2016/12 : 2071
# - 2017/12 : 2138
# - 2018/12 : 2199
# - 2019/12 : 2252

# %%
df['회계년도'].value_counts()
# Out:
# 2019/12    2252
# 2018/12    2199
# 2017/12    2138
# 2016/12    2071
# 2015/12    2003
# 2014/12    1915
# 2013/12    1826
# 2012/12    1768
# 2011/12    1722
# 2013/03      65
# 2011/03      64
# 2012/03      62
# 2014/03      30
# 2015/03      25
# 2016/03      23
# 2017/03      21
# 2019/03      20
# 2018/03      20
# 2011/06      18
# 2017/06      17
# 2012/06      17
# 2015/06      17
# 2014/06      16
# 2013/06      16
# 2016/06      15
# 2018/06      15
# 2019/06      14
# 2012/09      11
# 2011/09      11
# 2014/09       9
# 2013/09       9
# 2015/09       8
# 2019/09       6
# 2018/09       6
# 2017/09       6
# 2016/09       6
# 2011/11       2
# 2018/11       1
# 2017/11       1
# 2016/11       1
# 2015/11       1
# 2014/11       1
# 2018/08       1
# 2013/11       1
# 2012/11       1
# 2011/10       1
# 2019/08       1
# 2013/08       1
# 2017/08       1
# 2016/08       1
# 2015/08       1
# 2014/08       1
# 2012/08       1
# 2011/08       1
# 2019/02       1
# ...

# %%
df.drop(df[(df['회계년도'] != '2011/12') & (df['회계년도'] != '2012/12') & (df['회계년도'] != '2013/12') & (df['회계년도'] != '2014/12') & (df['회계년도'] != '2015/12') &
           (df['회계년도'] != '2016/12') & (df['회계년도'] != '2017/12') & (df['회계년도'] != '2018/12') & (df['회계년도'] != '2019/12')].index, inplace=True)

# %%
df
# Out:
#               회사명   거래소코드     회계년도  자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  \
# 0      (주)BNK금융지주  138930  2011/12     3.249906e+09     2.727816e+09
# 1      (주)BNK금융지주  138930  2012/12     3.403623e+09     2.740568e+09
# 2      (주)BNK금융지주  138930  2013/12     3.507652e+09     2.737860e+09
# 3      (주)BNK금융지주  138930  2014/12     4.539500e+09     3.550847e+09
# 4      (주)BNK금융지주  138930  2015/12     5.244360e+09     4.086109e+09
# ...           ...     ...      ...              ...              ...
# 18459     흥아해운(주)    3280  2015/12     7.712121e+08     1.618245e+08
# 18460     흥아해운(주)    3280  2016/12     9.425868e+08     1.838293e+08
# 18461     흥아해운(주)    3280  2017/12     8.341074e+08     1.076150e+08
# 18462     흥아해운(주)    3280  2018/12     7.827870e+08     5.673155e+07
# 18463     흥아해운(주)    3280  2019/12     3.865508e+08     1.763223e+07
#
#        부채(*)(IFRS)(천원)  매출액(영업수익)(*)(연결)(천원)  *주당순손익(IFRS연결)(천원)  \
# 0         5.220902e+08          3.057370e+09              2120.0
# ...

# %%
# 금융 관련 기업 제거
finance_list = [138930, 175330, 105560, 139130, 388790,  19570, 138040, 408920,
         1290,  55550,  21080, 316140,   6220, 323410, 355150, 246690,
         7330,  86790,  34830,  16610,   5830, 397880, 421800, 440790,
        30610, 293580, 298870,  30210,  27830, 387310,   3540,  82640,
       404950, 367340, 367360, 241520,    400, 277070,   8560, 353490,
       100790, 412930,  85620,   6800,   1270, 377630, 380320,  32830,
        16360,  29780,    810, 415580, 330730,  26890, 419270, 430220,
       445970, 366330, 393360, 405640,  23460, 405350,  27360,  19550,
         1510, 353070, 353060, 380440, 391060, 396770,   5940,  19590,
        41190,  10050, 435380, 367480, 430700,   3470, 373340, 388800,
       413630,   1200,   3460,  78020,  24110, 307930, 436530, 440200,
         3690,  16600, 413600,  39490, 446750, 388220, 400560, 406760,
       418170, 427950, 430230, 435620, 372290, 377400, 400840, 123890,
       409570, 436610,  23760,  71050,   1750,  88350,    370,   3530,
       386580,   1500,   1450,    540]

df[df['거래소코드']==540]

# %%
df.drop(df[df['거래소코드'] == 1450].index, inplace=True)

# %%
df.shape
# Out:
# (17471, 44)

# %%
df
# Out:
#             회사명  거래소코드     회계년도  자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  \
# 9      (주)CMG제약  58820  2011/12       27548539.0       18290915.0
# 10     (주)CMG제약  58820  2012/12       56988604.0       31602540.0
# 11     (주)CMG제약  58820  2013/12       55961620.0       49048213.0
# 12     (주)CMG제약  58820  2014/12       58127098.0       49067039.0
# 13     (주)CMG제약  58820  2015/12       56591972.0       46872705.0
# ...         ...    ...      ...              ...              ...
# 18459   흥아해운(주)   3280  2015/12      771212062.0      161824549.0
# 18460   흥아해운(주)   3280  2016/12      942586770.0      183829287.0
# 18461   흥아해운(주)   3280  2017/12      834107402.0      107614965.0
# 18462   흥아해운(주)   3280  2018/12      782787041.0       56731554.0
# 18463   흥아해운(주)   3280  2019/12      386550839.0       17632229.0
#
#        부채(*)(IFRS)(천원)  매출액(영업수익)(*)(연결)(천원)  *주당순손익(IFRS연결)(천원)  \
# 9            9257624.0            17751704.0               -35.0
# ...

# %%
df.to_csv('dataset.csv', index=False)

# %%
df['회계년도'] = df['회계년도'].apply(lambda x:x.replace('/12', ''))

# %%
df['회계년도'] = df['회계년도'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17471 entries, 9 to 18463
# Data columns (total 44 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   회사명                                 17471 non-null  object
#  1   거래소코드                               17471 non-null  int64
#  2   회계년도                                17471 non-null  int64
#  3   자산(*)(IFRS)(천원)                     16105 non-null  float64
#  4   자본(*)(IFRS)(천원)                     16105 non-null  float64
#  5   부채(*)(IFRS)(천원)                     16105 non-null  float64
#  6   매출액(영업수익)(*)(연결)(천원)                12135 non-null  float64
#  7   *주당순손익(IFRS연결)(천원)                  12103 non-null  float64
#  8   경상연구개발비(IFRS연결)(천원)                 12103 non-null  float64
#  9   광고 및 판매촉진비(IFRS연결)(천원)              12103 non-null  float64
#  10  임차료 및 리스료(IFRS연결)(천원)               12103 non-null  float64
# ...

# %%
df.to_csv('dataset2.csv', index=False)

# %%
df.drop(['기업규모명', '외국인_주식수(주)', '[공통]PCR(최고)(IFRS)','[공통]PCR(최저)(IFRS)',
'[공통]PSR(최고)(IFRS)','[공통]PSR(최저)(IFRS)', '거래량(주)', '최고가(원)', 
'최저가(원)', '거래년도(*)', '거래월(*)','거래일수','부채비율(IFRS연결)',
'총포괄이익증가율(IFRS연결)', '총포괄손익(IFRS연결)(천원)'], axis=1, inplace=True)

# %%
df
# Out:
#             회사명  거래소코드  회계년도  자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  \
# 9      (주)CMG제약  58820  2011       27548539.0       18290915.0
# 10     (주)CMG제약  58820  2012       56988604.0       31602540.0
# 11     (주)CMG제약  58820  2013       55961620.0       49048213.0
# 12     (주)CMG제약  58820  2014       58127098.0       49067039.0
# 13     (주)CMG제약  58820  2015       56591972.0       46872705.0
# ...         ...    ...   ...              ...              ...
# 18459   흥아해운(주)   3280  2015      771212062.0      161824549.0
# 18460   흥아해운(주)   3280  2016      942586770.0      183829287.0
# 18461   흥아해운(주)   3280  2017      834107402.0      107614965.0
# 18462   흥아해운(주)   3280  2018      782787041.0       56731554.0
# 18463   흥아해운(주)   3280  2019      386550839.0       17632229.0
#
#        부채(*)(IFRS)(천원)  매출액(영업수익)(*)(연결)(천원)  *주당순손익(IFRS연결)(천원)  \
# 9            9257624.0            17751704.0               -35.0
# 10          25386064.0            16255389.0              -138.0
# ...

# %%
df.to_csv('data2.csv', index=False)
